# %%
import plotly.express as px
from data import make_global_df

# %%
df = make_global_df()
df
# Out:
#          date  confirmed   deaths  recovered
# 0     1/22/20        557       17         30
# 1     1/23/20        655       18         32
# 2     1/24/20        941       26         39
# 3     1/25/20       1434       42         42
# 4     1/26/20       2118       56         56
# ..        ...        ...      ...        ...
# 637  10/20/21  242041201  4922187          0
# 638  10/21/21  242498401  4929777          0
# 639  10/22/21  242987401  4938251          0
# 640  10/23/21  243354428  4943926          0
# 641  10/24/21  243657129  4947967          0
#
# [642 rows x 4 columns]

# %%
fig = px.line(df, x="date", y=["confirmed","deaths","recovered"],
              template="plotly_dark",
              labels={
                "value":"cases",
                "variable":"Condition",
                "date":"Date",
            },
            hover_data={
                "value":":,",
                "variable": False,
                "date":False,
            })
fig.update_xaxes(rangeslider_visible=True)

fig["data"][0]["line"]["color"] = "#e74c3c"
fig["data"][1]["line"]["color"] = "#8e44ad"
fig["data"][2]["line"]["color"] = "#1abc9c"
fig
